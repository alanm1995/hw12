# %%
import os
import pandas as pd
import nltk
# %matplotlib inline

# %%
#from nltk.sentiment.vader import SentimentIntensityAnalyzer
#nltk.download("vader_lexicon")
#analyzer = SentimentIntensityAnalyzer()
from path import Path
import pandas as pd
import newsapi 
import nltk

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download("vader_lexicon")
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/Alan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
#from newsapi import NewsApiClient

# %%
# Fetch the Bitcoin news articles
#bit_articles
 #   q="bitcoin",
  #  language="en",
   # page_size=100,
    #sort_by="relevancy"
#)

# Print total articles
#print(f"Total articles about Bitcoin: ['totalResults']}")

# %%
# Fetch the Ethereum news articles
#ethereum_articles = newsapi.get_everything(
 #   q="ethereum",
  #  language="en",
   # page_size=100,
    #sort_by="relevancy"
#)

# Print total articles
#print(f"Total articles about Ethereum: {ethereum_articles['totalResults']}")

# %%
def create_df(news, language):
    articles = []
    for article in news:
        try:
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]

            articles.append({
                "title": title,
                "description": description,
                "text": text,
                "date": date,
                "language": language
            })
        except AttributeError:
            pass

    return pd.DataFrame(articles)
bitcoin_df = create_df(bit_articles["articles"], "en")
ethereum_df =create_df(ethereum_articles["articles"], "en")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-388f72fac769> in <module>
#      19
#      20     return pd.DataFrame(articles)
# ---> 21 bitcoin_df = create_df(bit_articles["articles"], "en")
#      22 ethereum_df =create_df(ethereum_articles["articles"], "en")
#
# NameError: name 'bit_articles' is not defined

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-bc3e331b5291> in <module>
#       2 bitcoin_sentiments = []
#       3
# ----> 4 for article in bitcoin_articles["articles"]:
#       5     try:
#       6         text = article["content"]
#
# NameError: name 'bitcoin_articles' is not defined

# %%
# Create the ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-261b6a1922b6> in <module>
#       2 ethereum_sentiments = []
#       3
# ----> 4 for article in ethereum_articles["articles"]:
#       5     try:
#       6         text = article["content"]
#
# NameError: name 'ethereum_articles' is not defined

# %%
# Describe the Bitcoin Sentiment

# %%
# Describe the Ethereum Sentiment

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum had a bigger mean positive score, but the delta was very marginal
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum had a higher compound score
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin had a highest postitive score of .249

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
sw_addon = {'ha', 'char', 'every', 'has', 'have', 'had', 'colleague'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    # Lemmatize Words into root words
    lemmatizer = WordNetLemmatizer() 
    lem = [lemmatizer.lemmatize(word) for word in words]
    #convert to lower and remove the stopwords 
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addon)]
            
    return tokens

# %%
# Create a new tokens column for bitcoin

# %%
# Create a new tokens column for ethereum

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2

# %%
# Generate the Ethereum N-grams where N=2

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin

# %%
# Get the top 10 words for Ethereum

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-0a1ecd929acc> in <module>
# ----> 1 from wordcloud import WordCloud
#       2 import matplotlib.pyplot as plt
#       3 plt.style.use('seaborn-whitegrid')
#       4 import matplotlib as mpl
#       5 mpl.rcParams['figure.figsize'] = [20.0, 10.0]
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# Generate the Bitcoin word cloud

# %%
# Generate the Ethereum word cloud

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-58-6f70af4282c0> in <module>
# ----> 1 import spacy
#       2 from spacy import displacy
#
# ModuleNotFoundError: No module named 'spacy'

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-298f4788b60f> in <module>
#       1 # Load the spaCy model
# ----> 2 nlp = spacy.load('en_core_web_sm')
#
# NameError: name 'spacy' is not defined

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bitcoin_sent = []
#for sent in bitcoin_tokens['text']:
    #sent_list = sent
    #bitcoin_sent.append(sent_list)
    
big_string_bitcoin = ' '.join(bitcoin_sent)

# %%
# Run the NER processor on all of the text

# Add a title to the document
bitcoin_doc = nlp(big_string_bitcoin)
bitcoin_doc.user_data['title'] = 'Bitcoin Name Entity Recognition'
displacy.render(bitcoin_doc, style='ent')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-9a793b511a94> in <module>
#       2
#       3 # Add a title to the document
# ----> 4 bitcoin_doc = nlp(big_string_bitcoin)
#       5 bitcoin_doc.user_data['title'] = 'Bitcoin Name Entity Recognition'
#       6 displacy.render(bitcoin_doc, style='ent')
#
# NameError: name 'nlp' is not defined

# %%
# Render the visualization

# %%
# List all Entities
for ent in bitcoin_doc.ents:
    print (ent, ent.label_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-d5ccb3f60e2d> in <module>
#       1 # List all Entities
# ----> 2 for ent in bitcoin_doc.ents:
#       3     print (ent, ent.label_)
#
# NameError: name 'bitcoin_doc' is not defined

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
eth_sent = []
for sent in ethereum_tokens['text']:
    sent_list_eth = sent
    eth_sent.append(sent_list_eth)
    
big_string_eth = " ".join(eth_sent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-b24550b82159> in <module>
#       1 # Concatenate all of the bitcoin text together
#       2 eth_sent = []
# ----> 3 for sent in ethereum_tokens['text']:
#       4     sent_list_eth = sent
#       5     eth_sent.append(sent_list_eth)
#
# NameError: name 'ethereum_tokens' is not defined

# %%
# Run the NER processor on all of the text

# Add a title to the document
eth_doc = nlp(big_string_eth)
eth_doc.user_data['title'] = 'Ethereum Named Entity Recogition'
displacy.render(eth_doc, style='ent')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-afb8a6f2352a> in <module>
#       2
#       3 # Add a title to the document
# ----> 4 eth_doc = nlp(big_string_eth)
#       5 eth_doc.user_data['title'] = 'Ethereum Named Entity Recogition'
#       6 displacy.render(eth_doc, style='ent')
#
# NameError: name 'nlp' is not defined

# %%
# Render the visualization

# %%
# List all Entities
#for ent in eth_doc.ents:
    #print (ent, ent.label_)
